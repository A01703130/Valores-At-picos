# %% [markdown]
# <a href="https://colab.research.google.com/github/A01703130/Valores-At-picos/blob/main/Actividad_3_2_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('gastos_2023_sin_nulos.csv')

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   397 non-null    int64
#  1   FECHA        397 non-null    object
#  2   FOLIO        397 non-null    object
#  3   UUID         397 non-null    object
#  4   RFC          397 non-null    object
#  5   PROOVEDOR    397 non-null    object
#  6   TIPO GASTO   397 non-null    object
#  7   DESCRIPCION  397 non-null    object
#  8   MP           397 non-null    object
#  9   FP           397 non-null    object
#  10  TC           397 non-null    float64
#  11  Importe      397 non-null    float64
#  12  IVA          397 non-null    float64
#  13  RET ISR      397 non-null    float64
#  14  RET IVA      397 non-null    float64
#  15  TOTAL MX     397 non-null    float64
#  16  TOTAL SAT    397 non-null    float64
#  17  TIPO         397 non-null    object
#  18  STATUS       397 non-null    object
#  19  POLIZA       397 non-null    object
# dtypes: float64(7), int64(1), object(12)
# memory usage: 62.2+ KB

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROOVEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# FP             0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %% [markdown]
# **PROCEDIMIENTO PARA ELIMINAR VALORES NULOS EN DATAFRAME**

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
#      Unnamed: 0       FECHA       FOLIO                                  UUID  \
# 0             0  2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1             1  2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2             2  2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3             3  2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4             4  2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931
# ..          ...         ...         ...                                   ...
# 392         392  2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33
# 393         393  2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444
# 394         394  2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7
# 395         395  2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1
# 396         396  2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706
#
#               RFC                                          PROOVEDOR  \
# 0    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 1    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 2    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 3    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 4    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ..            ...                                                ...
# 392  BIN940223KE0  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 393  BPU7901018D4                                BEBIDAS PURIFICADAS
# 394  BMN930209927  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...
# 395  EFE8908015L3                      EFECTIVALE S. de R.L. de C.V.
# 396  AAE6411055P8                          AESA ARTICULOS ELECTRICOS
#
#                    TIPO GASTO  \
# 0                     COMPRAS
# 1                     COMPRAS
# 2    ARRENDAMIENTO FINANCIERO
# 3    ARRENDAMIENTO FINANCIERO
# 4    ARRENDAMIENTO FINANCIERO
# ..                        ...
# 392         COMISION BANCARIA
# 393                 ALIMENTOS
# 394         COMISION BANCARIA
# 395                  GASOLINA
# 396                   COMPRAS
#
#                                            DESCRIPCION   MP    FP   TC  \
# 0                                                 Pago   --    --  1.0
# 1                                                 Pago   --    --  1.0
# 2    AA RENTA EXIGIBLE CL0000006876 30/36 de 03/12/...  PPD  99.0  1.0
# 3    AA RENTA EXIGIBLE CL0000006877 30/36 de 03/12/...  PPD  99.0  1.0
# 4    AA RENTA EXIGIBLE CL0000009486 5/48 de 03/12/2...  PPD  99.0  1.0
# ..                                                 ...  ...   ...  ...
# 392                             COMISIONES E INTERESES  PUE   3.0  1.0
# 393                         Epura 20 Lts Policarbonato  PUE   1.0  1.0
# 394                                SERVICIOS BANCARIOS  PUE   3.0  1.0
# 395  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS  PUE   5.0  1.0
# 396                                               Pago   --    --  1.0
#
#       Importe      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO   STATUS  \
# 0        0.00     0.00      0.0      0.0      0.00       0.00    P  Vigente
# 1        0.00     0.00      0.0      0.0      0.00       0.00    P  Vigente
# 2     5551.38   888.22      0.0      0.0   6439.60    6439.60    I  Vigente
# 3     5551.98   888.32      0.0      0.0   6440.30    6440.30    I  Vigente
# 4     8454.37  1352.70      0.0      0.0   9807.07    9807.07    I  Vigente
# ..        ...      ...      ...      ...       ...        ...  ...      ...
# 392      0.00     0.00      0.0      0.0      0.00       0.00    I  Vigente
# 393    220.00     0.00      0.0      0.0    220.00     220.00    I  Vigente
# 394  18071.52   682.40      0.0      0.0  18753.92   18753.92    I  Vigente
# 395  14472.32     0.00      0.0      0.0  14472.32   14472.32    I  Vigente
# 396      0.00     0.00      0.0      0.0      0.00       0.00    P  Vigente
#
#          POLIZA
# 0            --
# 1            --
# 2    PE01-ENE23
# 3    PE02-ENE23
# 4    PE03-ENE23
# ..          ...
# 392          --
# 393          --
# 394          --
# 395          --
# 396          --
#
# [397 rows x 20 columns]

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROOVEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# FP             0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "mean"
#Realizamos una copia del dataframe
data2=data.copy()
data2=data2.fillna(round(data.mean(),1))
data2
# Out:
# <ipython-input-8-1c13554a70f8>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2=data2.fillna(round(data.mean(),1))
#      Unnamed: 0       FECHA       FOLIO                                  UUID  \
# 0             0  2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1             1  2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2             2  2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3             3  2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4             4  2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931
# ..          ...         ...         ...                                   ...
# 392         392  2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33
# 393         393  2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444
# 394         394  2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7
# 395         395  2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1
# 396         396  2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706
#
#               RFC                                          PROOVEDOR  \
# 0    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 1    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 2    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 3    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 4    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ..            ...                                                ...
# 392  BIN940223KE0  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 393  BPU7901018D4                                BEBIDAS PURIFICADAS
# 394  BMN930209927  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...
# 395  EFE8908015L3                      EFECTIVALE S. de R.L. de C.V.
# 396  AAE6411055P8                          AESA ARTICULOS ELECTRICOS
#
#                    TIPO GASTO  \
# 0                     COMPRAS
# 1                     COMPRAS
# 2    ARRENDAMIENTO FINANCIERO
# 3    ARRENDAMIENTO FINANCIERO
# 4    ARRENDAMIENTO FINANCIERO
# ..                        ...
# 392         COMISION BANCARIA
# 393                 ALIMENTOS
# 394         COMISION BANCARIA
# 395                  GASOLINA
# 396                   COMPRAS
#
#                                            DESCRIPCION   MP    FP   TC  \
# 0                                                 Pago   --    --  1.0
# 1                                                 Pago   --    --  1.0
# 2    AA RENTA EXIGIBLE CL0000006876 30/36 de 03/12/...  PPD  99.0  1.0
# 3    AA RENTA EXIGIBLE CL0000006877 30/36 de 03/12/...  PPD  99.0  1.0
# 4    AA RENTA EXIGIBLE CL0000009486 5/48 de 03/12/2...  PPD  99.0  1.0
# ..                                                 ...  ...   ...  ...
# 392                             COMISIONES E INTERESES  PUE   3.0  1.0
# 393                         Epura 20 Lts Policarbonato  PUE   1.0  1.0
# 394                                SERVICIOS BANCARIOS  PUE   3.0  1.0
# 395  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS  PUE   5.0  1.0
# 396                                               Pago   --    --  1.0
#
#       Importe      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO   STATUS  \
# 0        0.00     0.00      0.0      0.0      0.00       0.00    P  Vigente
# 1        0.00     0.00      0.0      0.0      0.00       0.00    P  Vigente
# 2     5551.38   888.22      0.0      0.0   6439.60    6439.60    I  Vigente
# 3     5551.98   888.32      0.0      0.0   6440.30    6440.30    I  Vigente
# 4     8454.37  1352.70      0.0      0.0   9807.07    9807.07    I  Vigente
# ..        ...      ...      ...      ...       ...        ...  ...      ...
# 392      0.00     0.00      0.0      0.0      0.00       0.00    I  Vigente
# 393    220.00     0.00      0.0      0.0    220.00     220.00    I  Vigente
# 394  18071.52   682.40      0.0      0.0  18753.92   18753.92    I  Vigente
# 395  14472.32     0.00      0.0      0.0  14472.32   14472.32    I  Vigente
# 396      0.00     0.00      0.0      0.0      0.00       0.00    P  Vigente
#
#          POLIZA
# 0            --
# 1            --
# 2    PE01-ENE23
# 3    PE02-ENE23
# 4    PE03-ENE23
# ..          ...
# 392          --
# 393          --
# 394          --
# 395          --
# 396          --
#
# [397 rows x 20 columns]

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROOVEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# FP             0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido Unnamed: 0      542.244826
# TC                4.957143
# Importe       26557.244156
# IVA            3761.774707
# RET ISR         931.175004
# RET IVA        1022.471745
# TOTAL MX      29218.464899
# TOTAL SAT     29218.464899
# dtype: float64
# Limite inferior permitido Unnamed: 0     -146.244826
# TC               -2.774030
# Importe      -18708.366775
# IVA           -2766.954304
# RET ISR        -869.142712
# RET IVA        -947.124289
# TOTAL MX     -20512.146863
# TOTAL SAT    -20512.146863
# dtype: float64
# <ipython-input-11-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-11-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-11-4c899ed993c2>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()
# <ipython-input-11-4c899ed993c2>:4: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()

# %%
#Encontramos Ouliers del Dataframe
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-12-b3686d19c4d6>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
#      Unnamed: 0 FECHA FOLIO UUID  RFC PROOVEDOR TIPO GASTO DESCRIPCION   MP  \
# 0           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ..          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 392         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 393         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 394         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 395         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 396         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
#
#       FP  TC  Importe  IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO STATUS  \
# 0    NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
# 1    NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
# 2    NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
# 3    NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
# 4    NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
# ..   ...  ..      ...  ...      ...      ...       ...        ...  ...    ...
# 392  NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
# 393  NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
# 394  NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
# 395  NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
# 396  NaN NaN      NaN  NaN      NaN      NaN       NaN        NaN  NaN    NaN
#
#     POLIZA
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 392    NaN
# 393    NaN
# 394    NaN
# 395    NaN
# 396    NaN
#
# [397 rows x 20 columns]

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
# <ipython-input-13-1e038dbc0c4a>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#      Unnamed: 0 FECHA FOLIO UUID  RFC PROOVEDOR TIPO GASTO DESCRIPCION   MP  \
# 0             0   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1             1   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2             2   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3             3   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4             4   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ..          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 392         392   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 393         393   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 394         394   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 395         395   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 396         396   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
#
#       FP   TC   Importe      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO  \
# 0    NaN  1.0      0.00     0.00      0.0      0.0      0.00       0.00  NaN
# 1    NaN  1.0      0.00     0.00      0.0      0.0      0.00       0.00  NaN
# 2    NaN  1.0   5551.38   888.22      0.0      0.0   6439.60    6439.60  NaN
# 3    NaN  1.0   5551.98   888.32      0.0      0.0   6440.30    6440.30  NaN
# 4    NaN  1.0   8454.37  1352.70      0.0      0.0   9807.07    9807.07  NaN
# ..   ...  ...       ...      ...      ...      ...       ...        ...  ...
# 392  NaN  1.0      0.00     0.00      0.0      0.0      0.00       0.00  NaN
# 393  NaN  1.0    220.00     0.00      0.0      0.0    220.00     220.00  NaN
# 394  NaN  1.0  18071.52   682.40      0.0      0.0  18753.92   18753.92  NaN
# 395  NaN  1.0  14472.32     0.00      0.0      0.0  14472.32   14472.32  NaN
# 396  NaN  1.0      0.00     0.00      0.0      0.0      0.00       0.00  NaN
#
#     STATUS POLIZA
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# ..     ...    ...
# 392    NaN    NaN
# 393    NaN    NaN
# 394    NaN    NaN
# 395    NaN    NaN
# 396    NaN    NaN
#
# [397 rows x 20 columns]

# %%
#Eliminamos columnas innecesarias
data4= data3.drop(["FECHA","FOLIO","UUID","TC","RFC","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"], axis=1)
data4
# Out:
#      Unnamed: 0 PROOVEDOR   MP   FP   Importe      IVA  RET ISR  RET IVA  \
# 0             0       NaN  NaN  NaN      0.00     0.00      0.0      0.0
# 1             1       NaN  NaN  NaN      0.00     0.00      0.0      0.0
# 2             2       NaN  NaN  NaN   5551.38   888.22      0.0      0.0
# 3             3       NaN  NaN  NaN   5551.98   888.32      0.0      0.0
# 4             4       NaN  NaN  NaN   8454.37  1352.70      0.0      0.0
# ..          ...       ...  ...  ...       ...      ...      ...      ...
# 392         392       NaN  NaN  NaN      0.00     0.00      0.0      0.0
# 393         393       NaN  NaN  NaN    220.00     0.00      0.0      0.0
# 394         394       NaN  NaN  NaN  18071.52   682.40      0.0      0.0
# 395         395       NaN  NaN  NaN  14472.32     0.00      0.0      0.0
# 396         396       NaN  NaN  NaN      0.00     0.00      0.0      0.0
#
#      TOTAL MX  TOTAL SAT
# 0        0.00       0.00
# 1        0.00       0.00
# 2     6439.60    6439.60
# 3     6440.30    6440.30
# 4     9807.07    9807.07
# ..        ...        ...
# 392      0.00       0.00
# 393    220.00     220.00
# 394  18753.92   18753.92
# 395  14472.32   14472.32
# 396      0.00       0.00
#
# [397 rows x 10 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data4.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0      0
# PROOVEDOR     397
# MP            397
# FP            397
# Importe        13
# IVA            13
# RET ISR         4
# RET IVA         6
# TOTAL MX        9
# TOTAL SAT       9
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data4.copy()
data_clean=data_clean.fillna(round(data4.mean(),1))
data_clean
# Out:
#      Unnamed: 0  PROOVEDOR  MP  FP   Importe      IVA  RET ISR  RET IVA  \
# 0             0        NaN NaN NaN      0.00     0.00      0.0      0.0
# 1             1        NaN NaN NaN      0.00     0.00      0.0      0.0
# 2             2        NaN NaN NaN   5551.38   888.22      0.0      0.0
# 3             3        NaN NaN NaN   5551.98   888.32      0.0      0.0
# 4             4        NaN NaN NaN   8454.37  1352.70      0.0      0.0
# ..          ...        ...  ..  ..       ...      ...      ...      ...
# 392         392        NaN NaN NaN      0.00     0.00      0.0      0.0
# 393         393        NaN NaN NaN    220.00     0.00      0.0      0.0
# 394         394        NaN NaN NaN  18071.52   682.40      0.0      0.0
# 395         395        NaN NaN NaN  14472.32     0.00      0.0      0.0
# 396         396        NaN NaN NaN      0.00     0.00      0.0      0.0
#
#      TOTAL MX  TOTAL SAT
# 0        0.00       0.00
# 1        0.00       0.00
# 2     6439.60    6439.60
# 3     6440.30    6440.30
# 4     9807.07    9807.07
# ..        ...        ...
# 392      0.00       0.00
# 393    220.00     220.00
# 394  18753.92   18753.92
# 395  14472.32   14472.32
# 396      0.00       0.00
#
# [397 rows x 10 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0      0
# PROOVEDOR     397
# MP            397
# FP            397
# Importe         0
# IVA             0
# RET ISR         0
# RET IVA         0
# TOTAL MX        0
# TOTAL SAT       0
# dtype: int64

# %%
# Unimos las columnas con el dataframe

cols=data2["FECHA"]
cols1=data2["FOLIO"]
cols2=data2["UUID"]
cols3=data2["TC"]
cols5=data2["RFC"]
cols6=data2["TIPO GASTO"]
cols8=data2["DESCRIPCION"]
cols9=data2["TIPO"]
cols10=data2["STATUS"]
cols11=data2["POLIZA"]

#"FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"
Datos_limpios = pd.concat([cols,cols1,cols2,cols3,cols5,cols6,cols8,cols9,cols10,cols11,data_clean], axis=1)
Datos_limpios
# Out:
#           FECHA       FOLIO                                  UUID   TC  \
# 0    2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E  1.0
# 1    2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7  1.0
# 2    2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44  1.0
# 3    2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021  1.0
# 4    2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931  1.0
# ..          ...         ...                                   ...  ...
# 392  2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33  1.0
# 393  2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444  1.0
# 394  2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7  1.0
# 395  2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1  1.0
# 396  2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706  1.0
#
#               RFC                TIPO GASTO  \
# 0    AAE6411055P8                   COMPRAS
# 1    AAE6411055P8                   COMPRAS
# 2    BLE1512082R9  ARRENDAMIENTO FINANCIERO
# 3    BLE1512082R9  ARRENDAMIENTO FINANCIERO
# 4    BLE1512082R9  ARRENDAMIENTO FINANCIERO
# ..            ...                       ...
# 392  BIN940223KE0         COMISION BANCARIA
# 393  BPU7901018D4                 ALIMENTOS
# 394  BMN930209927         COMISION BANCARIA
# 395  EFE8908015L3                  GASOLINA
# 396  AAE6411055P8                   COMPRAS
#
#                                            DESCRIPCION TIPO   STATUS  \
# 0                                                 Pago    P  Vigente
# 1                                                 Pago    P  Vigente
# 2    AA RENTA EXIGIBLE CL0000006876 30/36 de 03/12/...    I  Vigente
# 3    AA RENTA EXIGIBLE CL0000006877 30/36 de 03/12/...    I  Vigente
# 4    AA RENTA EXIGIBLE CL0000009486 5/48 de 03/12/2...    I  Vigente
# ..                                                 ...  ...      ...
# 392                             COMISIONES E INTERESES    I  Vigente
# 393                         Epura 20 Lts Policarbonato    I  Vigente
# 394                                SERVICIOS BANCARIOS    I  Vigente
# 395  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS    I  Vigente
# 396                                               Pago    P  Vigente
#
#          POLIZA  Unnamed: 0  PROOVEDOR  MP  FP   Importe      IVA  RET ISR  \
# 0            --           0        NaN NaN NaN      0.00     0.00      0.0
# 1            --           1        NaN NaN NaN      0.00     0.00      0.0
# 2    PE01-ENE23           2        NaN NaN NaN   5551.38   888.22      0.0
# 3    PE02-ENE23           3        NaN NaN NaN   5551.98   888.32      0.0
# 4    PE03-ENE23           4        NaN NaN NaN   8454.37  1352.70      0.0
# ..          ...         ...        ...  ..  ..       ...      ...      ...
# 392          --         392        NaN NaN NaN      0.00     0.00      0.0
# 393          --         393        NaN NaN NaN    220.00     0.00      0.0
# 394          --         394        NaN NaN NaN  18071.52   682.40      0.0
# 395          --         395        NaN NaN NaN  14472.32     0.00      0.0
# 396          --         396        NaN NaN NaN      0.00     0.00      0.0
#
#      RET IVA  TOTAL MX  TOTAL SAT
# 0        0.0      0.00       0.00
# 1        0.0      0.00       0.00
# 2        0.0   6439.60    6439.60
# 3        0.0   6440.30    6440.30
# 4        0.0   9807.07    9807.07
# ..       ...       ...        ...
# 392      0.0      0.00       0.00
# 393      0.0    220.00     220.00
# 394      0.0  18753.92   18753.92
# 395      0.0  14472.32   14472.32
# 396      0.0      0.00       0.00
#
# [397 rows x 20 columns]

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("Datos_limpios2023_des.csv")

# %% [markdown]
# **PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido Unnamed: 0      594.00
# TC                1.00
# Importe        9075.43
# IVA            1120.00
# RET ISR           0.00
# RET IVA           0.00
# TOTAL MX      10527.50
# TOTAL SAT     10527.50
# dtype: float64
# Limite inferior permitido Unnamed: 0    -198.00
# TC               1.00
# Importe      -5259.05
# IVA           -672.00
# RET ISR          0.00
# RET IVA          0.00
# TOTAL MX     -6100.50
# TOTAL SAT    -6100.50
# dtype: float64
# <ipython-input-18-fa2f126c26b8>:4: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   percentile25=y.quantile(0.25) #Q1
# <ipython-input-18-fa2f126c26b8>:5: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   percentile75=y.quantile(0.75) #Q3

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# <ipython-input-19-3f17fc13e977>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
#      Unnamed: 0 FECHA FOLIO UUID  RFC PROOVEDOR TIPO GASTO DESCRIPCION   MP  \
# 0           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4           NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ..          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 392         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 393         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 394         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 395         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 396         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
#
#       FP  TC   Importe     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO  \
# 0    NaN NaN       NaN     NaN      NaN      NaN       NaN        NaN  NaN
# 1    NaN NaN       NaN     NaN      NaN      NaN       NaN        NaN  NaN
# 2    NaN NaN       NaN     NaN      NaN      NaN       NaN        NaN  NaN
# 3    NaN NaN       NaN     NaN      NaN      NaN       NaN        NaN  NaN
# 4    NaN NaN       NaN  1352.7      NaN      NaN       NaN        NaN  NaN
# ..   ...  ..       ...     ...      ...      ...       ...        ...  ...
# 392  NaN NaN       NaN     NaN      NaN      NaN       NaN        NaN  NaN
# 393  NaN NaN       NaN     NaN      NaN      NaN       NaN        NaN  NaN
# 394  NaN NaN  18071.52     NaN      NaN      NaN  18753.92   18753.92  NaN
# 395  NaN NaN  14472.32     NaN      NaN      NaN  14472.32   14472.32  NaN
# 396  NaN NaN       NaN     NaN      NaN      NaN       NaN        NaN  NaN
#
#     STATUS POLIZA
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# ..     ...    ...
# 392    NaN    NaN
# 393    NaN    NaN
# 394    NaN    NaN
# 395    NaN    NaN
# 396    NaN    NaN
#
# [397 rows x 20 columns]

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
# <ipython-input-20-bfdf7956f233>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3_iqr= data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
#      Unnamed: 0 FECHA FOLIO UUID  RFC PROOVEDOR TIPO GASTO DESCRIPCION   MP  \
# 0             0   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1             1   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2             2   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3             3   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4             4   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ..          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 392         392   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 393         393   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 394         394   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 395         395   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 396         396   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
#
#       FP   TC  Importe     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT TIPO  \
# 0    NaN  1.0     0.00    0.00      0.0      0.0      0.00       0.00  NaN
# 1    NaN  1.0     0.00    0.00      0.0      0.0      0.00       0.00  NaN
# 2    NaN  1.0  5551.38  888.22      0.0      0.0   6439.60    6439.60  NaN
# 3    NaN  1.0  5551.98  888.32      0.0      0.0   6440.30    6440.30  NaN
# 4    NaN  1.0  8454.37     NaN      0.0      0.0   9807.07    9807.07  NaN
# ..   ...  ...      ...     ...      ...      ...       ...        ...  ...
# 392  NaN  1.0     0.00    0.00      0.0      0.0      0.00       0.00  NaN
# 393  NaN  1.0   220.00    0.00      0.0      0.0    220.00     220.00  NaN
# 394  NaN  1.0      NaN  682.40      0.0      0.0       NaN        NaN  NaN
# 395  NaN  1.0      NaN    0.00      0.0      0.0       NaN        NaN  NaN
# 396  NaN  1.0     0.00    0.00      0.0      0.0      0.00       0.00  NaN
#
#     STATUS POLIZA
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# ..     ...    ...
# 392    NaN    NaN
# 393    NaN    NaN
# 394    NaN    NaN
# 395    NaN    NaN
# 396    NaN    NaN
#
# [397 rows x 20 columns]

# %%
#Eliminamos columnas innecesarias
data4_iqr= data3_iqr.drop(["FECHA","FOLIO","UUID","TC","RFC","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"], axis=1)
data4_iqr
# Out:
#      Unnamed: 0 PROOVEDOR   MP   FP  Importe     IVA  RET ISR  RET IVA  \
# 0             0       NaN  NaN  NaN     0.00    0.00      0.0      0.0
# 1             1       NaN  NaN  NaN     0.00    0.00      0.0      0.0
# 2             2       NaN  NaN  NaN  5551.38  888.22      0.0      0.0
# 3             3       NaN  NaN  NaN  5551.98  888.32      0.0      0.0
# 4             4       NaN  NaN  NaN  8454.37     NaN      0.0      0.0
# ..          ...       ...  ...  ...      ...     ...      ...      ...
# 392         392       NaN  NaN  NaN     0.00    0.00      0.0      0.0
# 393         393       NaN  NaN  NaN   220.00    0.00      0.0      0.0
# 394         394       NaN  NaN  NaN      NaN  682.40      0.0      0.0
# 395         395       NaN  NaN  NaN      NaN    0.00      0.0      0.0
# 396         396       NaN  NaN  NaN     0.00    0.00      0.0      0.0
#
#      TOTAL MX  TOTAL SAT
# 0        0.00       0.00
# 1        0.00       0.00
# 2     6439.60    6439.60
# 3     6440.30    6440.30
# 4     9807.07    9807.07
# ..        ...        ...
# 392      0.00       0.00
# 393    220.00     220.00
# 394       NaN        NaN
# 395       NaN        NaN
# 396      0.00       0.00
#
# [397 rows x 10 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data4_iqr.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0      0
# PROOVEDOR     397
# MP            397
# FP            397
# Importe        50
# IVA            49
# RET ISR         9
# RET IVA         9
# TOTAL MX       46
# TOTAL SAT      46
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data5_iqr=data4_iqr.copy()
data5_iqr=data5_iqr.fillna(round(data4_iqr.mean(),1))
data5_iqr
# Out:
#      Unnamed: 0  PROOVEDOR  MP  FP  Importe     IVA  RET ISR  RET IVA  \
# 0             0        NaN NaN NaN     0.00    0.00      0.0      0.0
# 1             1        NaN NaN NaN     0.00    0.00      0.0      0.0
# 2             2        NaN NaN NaN  5551.38  888.22      0.0      0.0
# 3             3        NaN NaN NaN  5551.98  888.32      0.0      0.0
# 4             4        NaN NaN NaN  8454.37  176.80      0.0      0.0
# ..          ...        ...  ..  ..      ...     ...      ...      ...
# 392         392        NaN NaN NaN     0.00    0.00      0.0      0.0
# 393         393        NaN NaN NaN   220.00    0.00      0.0      0.0
# 394         394        NaN NaN NaN  1521.50  682.40      0.0      0.0
# 395         395        NaN NaN NaN  1521.50    0.00      0.0      0.0
# 396         396        NaN NaN NaN     0.00    0.00      0.0      0.0
#
#      TOTAL MX  TOTAL SAT
# 0        0.00       0.00
# 1        0.00       0.00
# 2     6439.60    6439.60
# 3     6440.30    6440.30
# 4     9807.07    9807.07
# ..        ...        ...
# 392      0.00       0.00
# 393    220.00     220.00
# 394   1845.00    1845.00
# 395   1845.00    1845.00
# 396      0.00       0.00
#
# [397 rows x 10 columns]

# %%
# Unimos las columnas con el dataframe

cols=data2["FECHA"]
cols1=data2["FOLIO"]
cols2=data2["UUID"]
cols3=data2["TC"]
cols5=data2["RFC"]
cols6=data2["TIPO GASTO"]
cols8=data2["DESCRIPCION"]
cols9=data2["TIPO"]
cols10=data2["STATUS"]
cols11=data2["POLIZA"]

#"FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"
Datos_limpios1 = pd.concat([cols,cols1,cols2,cols3,cols5,cols6,cols8,cols9,cols10,cols11, data5_iqr], axis=1)
Datos_limpios1
# Out:
#           FECHA       FOLIO                                  UUID   TC  \
# 0    2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E  1.0
# 1    2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7  1.0
# 2    2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44  1.0
# 3    2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021  1.0
# 4    2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931  1.0
# ..          ...         ...                                   ...  ...
# 392  2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33  1.0
# 393  2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444  1.0
# 394  2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7  1.0
# 395  2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1  1.0
# 396  2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706  1.0
#
#               RFC                TIPO GASTO  \
# 0    AAE6411055P8                   COMPRAS
# 1    AAE6411055P8                   COMPRAS
# 2    BLE1512082R9  ARRENDAMIENTO FINANCIERO
# 3    BLE1512082R9  ARRENDAMIENTO FINANCIERO
# 4    BLE1512082R9  ARRENDAMIENTO FINANCIERO
# ..            ...                       ...
# 392  BIN940223KE0         COMISION BANCARIA
# 393  BPU7901018D4                 ALIMENTOS
# 394  BMN930209927         COMISION BANCARIA
# 395  EFE8908015L3                  GASOLINA
# 396  AAE6411055P8                   COMPRAS
#
#                                            DESCRIPCION TIPO   STATUS  \
# 0                                                 Pago    P  Vigente
# 1                                                 Pago    P  Vigente
# 2    AA RENTA EXIGIBLE CL0000006876 30/36 de 03/12/...    I  Vigente
# 3    AA RENTA EXIGIBLE CL0000006877 30/36 de 03/12/...    I  Vigente
# 4    AA RENTA EXIGIBLE CL0000009486 5/48 de 03/12/2...    I  Vigente
# ..                                                 ...  ...      ...
# 392                             COMISIONES E INTERESES    I  Vigente
# 393                         Epura 20 Lts Policarbonato    I  Vigente
# 394                                SERVICIOS BANCARIOS    I  Vigente
# 395  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS    I  Vigente
# 396                                               Pago    P  Vigente
#
#          POLIZA  Unnamed: 0  PROOVEDOR  MP  FP  Importe     IVA  RET ISR  \
# 0            --           0        NaN NaN NaN     0.00    0.00      0.0
# 1            --           1        NaN NaN NaN     0.00    0.00      0.0
# 2    PE01-ENE23           2        NaN NaN NaN  5551.38  888.22      0.0
# 3    PE02-ENE23           3        NaN NaN NaN  5551.98  888.32      0.0
# 4    PE03-ENE23           4        NaN NaN NaN  8454.37  176.80      0.0
# ..          ...         ...        ...  ..  ..      ...     ...      ...
# 392          --         392        NaN NaN NaN     0.00    0.00      0.0
# 393          --         393        NaN NaN NaN   220.00    0.00      0.0
# 394          --         394        NaN NaN NaN  1521.50  682.40      0.0
# 395          --         395        NaN NaN NaN  1521.50    0.00      0.0
# 396          --         396        NaN NaN NaN     0.00    0.00      0.0
#
#      RET IVA  TOTAL MX  TOTAL SAT
# 0        0.0      0.00       0.00
# 1        0.0      0.00       0.00
# 2        0.0   6439.60    6439.60
# 3        0.0   6440.30    6440.30
# 4        0.0   9807.07    9807.07
# ..       ...       ...        ...
# 392      0.0      0.00       0.00
# 393      0.0    220.00     220.00
# 394      0.0   1845.00    1845.00
# 395      0.0   1845.00    1845.00
# 396      0.0      0.00       0.00
#
# [397 rows x 20 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# FECHA            0
# FOLIO            0
# UUID             0
# TC               0
# RFC              0
# TIPO GASTO       0
# DESCRIPCION      0
# TIPO             0
# STATUS           0
# POLIZA           0
# Unnamed: 0       0
# PROOVEDOR      397
# MP             397
# FP             397
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# dtype: int64

# %%
#Convertir DataFrame a CSV
Datos_limpios1.to_csv("Datos_limpios2023_cuar.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Datos_limpios2023_cuar.csv")
