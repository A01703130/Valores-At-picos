# %% [markdown]
# <a href="https://colab.research.google.com/github/A01703130/Valores-At-picos/blob/main/Actividad_3_2_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('gastos_2021_sin_nulos.csv')

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3035 non-null   int64
#  1   FECHA        3035 non-null   object
#  2   FOLIO        3035 non-null   object
#  3   UUID         3035 non-null   object
#  4   RFC          3035 non-null   object
#  5   PROVEEDOR    3035 non-null   object
#  6   TIPO GASTO   3035 non-null   object
#  7   DESCRIPCION  3035 non-null   object
#  8   MP           3035 non-null   object
#  9   TC           3035 non-null   float64
#  10  IMPORTE      3035 non-null   float64
#  11  IVA          3035 non-null   float64
#  12  RET ISR      3035 non-null   float64
#  13  RET IVA      3035 non-null   float64
#  14  TOTAL MX     3035 non-null   float64
#  15  TOTAL SAT    3035 non-null   float64
#  16  TIPO         3035 non-null   object
#  17  STATUS       3035 non-null   object
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %% [markdown]
# **PROCEDIMIENTO PARA ELIMINAR VALORES NULOS EN DATAFRAME**

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
#       Unnamed: 0       FECHA                   FOLIO  \
# 0              0  2021-01-01  0001010100750847116902
# 1              1  2021-01-01  0001010100752163714102
# 2              2  2021-01-01                   19788
# 3              3  2021-01-01                  211781
# 4              4  2021-01-01                  211782
# ...          ...         ...                     ...
# 3030        3030  2021-12-01                  127043
# 3031        3031  2021-12-01                   11740
# 3032        3032  2021-12-01              1092957089
# 3033        3033  2021-12-01                  747826
# 3034        3034  2021-12-01                 1227374
#
#                                       UUID           RFC  \
# 0     71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B  BNM840515VB1
# 1     B8AEDE83-CC76-404C-A611-6B5A87BA561F  BNM840515VB1
# 2     19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7  ESI9612311E7
# 3     EAB26414-DD9A-4E8F-9F5C-05FE24D98E48  BLE1512082R9
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "mean"
#Realizamos una copia del dataframe
data2=data.copy()
data2=data2.fillna(round(data.mean(),1))
data2
# Out:
# <ipython-input-7-1c13554a70f8>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2=data2.fillna(round(data.mean(),1))
#       Unnamed: 0       FECHA                   FOLIO  \
# 0              0  2021-01-01  0001010100750847116902
# 1              1  2021-01-01  0001010100752163714102
# 2              2  2021-01-01                   19788
# 3              3  2021-01-01                  211781
# 4              4  2021-01-01                  211782
# ...          ...         ...                     ...
# 3030        3030  2021-12-01                  127043
# 3031        3031  2021-12-01                   11740
# 3032        3032  2021-12-01              1092957089
# 3033        3033  2021-12-01                  747826
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido Unnamed: 0     4145.820078
# TC                6.286851
# IMPORTE       36154.569820
# IVA            5464.876801
# RET ISR         900.150092
# RET IVA        1200.884906
# TOTAL MX      40680.462408
# TOTAL SAT     40671.985064
# dtype: float64
# Limite inferior permitido Unnamed: 0    -1111.820078
# TC               -3.981398
# IMPORTE      -27625.812771
# IVA           -4276.811367
# RET ISR        -833.428945
# RET IVA       -1053.848939
# TOTAL MX     -31176.694132
# TOTAL SAT    -31129.503410
# dtype: float64
# <ipython-input-10-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# ...

# %%
#Encontramos Ouliers del Dataframe
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-11-b3686d19c4d6>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROVEEDOR TIPO GASTO DESCRIPCION   MP  \
# 0            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 3030         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
# <ipython-input-12-1e038dbc0c4a>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROVEEDOR TIPO GASTO DESCRIPCION   MP  \
# 0              0   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1              1   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2              2   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3              3   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4              4   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 3030        3030   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...

# %%
#Eliminamos columnas innecesarias
data4= data3.drop(["FECHA","FOLIO","UUID","TC","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"], axis=1)
data4
# Out:
#       Unnamed: 0   MP   IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0              0  NaN    490.00   78.40      0.0      0.0    568.40     568.40
# 1              1  NaN    345.00   55.20      0.0      0.0    400.20     400.20
# 2              2  NaN   3447.41  551.59      0.0      0.0   3999.00    3999.00
# 3              3  NaN   5551.38  888.22      0.0      0.0   6439.60    6439.60
# 4              4  NaN   5551.98  888.32      0.0      0.0   6440.30    6440.30
# ...          ...  ...       ...     ...      ...      ...       ...        ...
# 3030        3030  NaN      0.00    0.00      0.0      0.0      0.00       0.00
# 3031        3031  NaN      0.00    0.00      0.0      0.0      0.00       0.00
# 3032        3032  NaN  22826.46  705.58      0.0      0.0  23532.04   23532.04
# 3033        3033  NaN      0.00    0.00      0.0      0.0      0.00       0.00
# 3034        3034  NaN  15656.15    0.00      0.0      0.0  15656.15   15656.15
#
# [3035 rows x 8 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data4.isnull().sum()
valores_nulos

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data4.copy()
data_clean=data_clean.fillna(round(data4.mean(),1))
data_clean

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos

# %%
# Unimos las columnas con el dataframe

cols=data2["FECHA"]
cols1=data2["FOLIO"]
cols2=data2["UUID"]
cols3=data2["TC"]
cols5=data2["RFC"]
cols6=data2["TIPO GASTO"]
cols7=data2["PROVEEDOR"]
cols8=data2["DESCRIPCION"]
cols9=data2["TIPO"]
cols10=data2["STATUS"]
cols11=data2["POLIZA"]

#"FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"
Datos_limpios = pd.concat([cols,cols1,cols2,cols3,cols5,cols6,cols7,cols8,cols9,cols10,cols11, data_clean], axis=1)
Datos_limpios

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("Datos_limpios2021_desv.csv")

# %% [markdown]
# **PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr

# %%
#Eliminamos columnas innecesarias
data4_iqr= data3_iqr.drop(["FECHA","FOLIO","UUID","TC","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"], axis=1)
data4_iqr

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data4_iqr.isnull().sum()
valores_nulos

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data5_iqr=data4_iqr.copy()
data5_iqr=data5_iqr.fillna(round(data4_iqr.mean(),1))
data5_iqr

# %%
# Unimos las columnas con el dataframe

cols=data2["FECHA"]
cols1=data2["FOLIO"]
cols2=data2["UUID"]
cols3=data2["TC"]
cols5=data2["RFC"]
cols6=data2["TIPO GASTO"]
cols7=data2["PROVEEDOR"]
cols8=data2["DESCRIPCION"]
cols9=data2["TIPO"]
cols10=data2["STATUS"]
cols11=data2["POLIZA"]

#"FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"
Datos_limpios1 = pd.concat([cols,cols1,cols2,cols3,cols5,cols6,cols7,cols8,cols9,cols10,cols11, data5_iqr], axis=1)
Datos_limpios1

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos

# %%
#Convertir DataFrame a CSV
Datos_limpios1.to_csv("Datos_limpios2021_cuart.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Datos_limpios2021_cuart.csv")
