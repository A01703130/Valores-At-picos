# %% [markdown]
# <a href="https://colab.research.google.com/github/A01703130/Valores-At-picos/blob/main/Actividad_3_2_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('gastos_2020_sin_nulos.csv')

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3342 non-null   int64
#  1   FECHA        3342 non-null   object
#  2   FOLIO        3342 non-null   object
#  3   UUID         3342 non-null   object
#  4   RFC          3342 non-null   object
#  5   PROVEEDOR    3342 non-null   object
#  6   TIPO GASTO   3342 non-null   object
#  7   GASTO        3342 non-null   object
#  8   DESCRIPCION  3342 non-null   object
#  9   TC           3342 non-null   object
#  10  IMPORTE      3342 non-null   float64
#  11  IVA          3342 non-null   float64
#  12  RET ISR      3342 non-null   float64
#  13  RET IVA      3342 non-null   float64
#  14  TOTAL MX     3342 non-null   float64
#  15  TOTAL SAT    3342 non-null   float64
#  16  TIPO         3342 non-null   object
#  17  STATUS       3342 non-null   object
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# GASTO          0
# DESCRIPCION    0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# Columna1       0
# dtype: int64

# %% [markdown]
# **PROCEDIMIENTO PARA ELIMINAR VALORES NULOS EN DATAFRAME**

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
#       Unnamed: 0       FECHA                   FOLIO  \
# 0              0  2020-01-01                   39408
# 1              1  2020-01-01  0001010100750847116902
# 2              2  2020-01-01  0001010100752163714102
# 3              3  2020-01-01                    3663
# 4              4  2020-01-01                    2849
# ...          ...         ...                     ...
# 3337        3337  2020-12-01                  125834
# 3338        3338  2020-12-01                   37652
# 3339        3339  2020-12-01                     160
# 3340        3340  2020-12-01                  634875
# 3341        3341  2020-12-01                 1044477
#
#                                       UUID           RFC  \
# 0     BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 1     85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 2     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 3     EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# GASTO          0
# DESCRIPCION    0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# Columna1       0
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "mean"
#Realizamos una copia del dataframe
data2=data.copy()
data2=data2.fillna(round(data.mean(),1))
data2
# Out:
# <ipython-input-32-1c13554a70f8>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2=data2.fillna(round(data.mean(),1))
#       Unnamed: 0       FECHA                   FOLIO  \
# 0              0  2020-01-01                   39408
# 1              1  2020-01-01  0001010100750847116902
# 2              2  2020-01-01  0001010100752163714102
# 3              3  2020-01-01                    3663
# 4              4  2020-01-01                    2849
# ...          ...         ...                     ...
# 3337        3337  2020-12-01                  125834
# 3338        3338  2020-12-01                   37652
# 3339        3339  2020-12-01                     160
# 3340        3340  2020-12-01                  634875
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# GASTO          0
# DESCRIPCION    0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# Columna1       0
# dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido Unnamed: 0     4565.189880
# IMPORTE       25155.492600
# IVA            4543.784701
# RET ISR         667.271992
# RET IVA         958.239955
# TOTAL MX      28488.002843
# TOTAL SAT     33250.398514
# Columna1      14626.999268
# dtype: float64
# Limite inferior permitido Unnamed: 0    -1224.189880
# IMPORTE      -18910.907561
# IVA           -3574.050028
# RET ISR        -627.750813
# RET IVA        -839.215179
# TOTAL MX     -21455.655297
# TOTAL SAT    -25762.462834
# Columna1     -14171.411134
# dtype: float64
# <ipython-input-35-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# ...

# %%
#Encontramos Ouliers del Dataframe
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-36-b3686d19c4d6>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROVEEDOR TIPO GASTO GASTO DESCRIPCION  \
# 0            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 1            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 2            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 3            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 4            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# ...          ...   ...   ...  ...  ...       ...        ...   ...         ...
# 3337         NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
# <ipython-input-37-1e038dbc0c4a>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROVEEDOR TIPO GASTO GASTO DESCRIPCION  \
# 0              0   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 1              1   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 2              2   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 3              3   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 4              4   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# ...          ...   ...   ...  ...  ...       ...        ...   ...         ...
# 3337        3337   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# ...

# %%
#Eliminamos columnas innecesarias
data4= data3.drop(["FECHA","FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"], axis=1)
data4
# Out:
#       Unnamed: 0   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0              0      0.00  2248.28      0.0      0.0   2248.28   16300.00
# 1              1    490.00    78.40      0.0      0.0    568.40     568.40
# 2              2    195.00    31.20      0.0      0.0    226.20     226.20
# 3              3  10694.25  1711.08      0.0      0.0  12405.33   12405.33
# 4              4      0.00    83.90      0.0      0.0      0.00       0.00
# ...          ...       ...      ...      ...      ...       ...        ...
# 3337        3337    129.79    20.21      0.0      0.0    150.00     150.00
# 3338        3338   2284.80   365.57      0.0      0.0   2650.37    2650.37
# 3339        3339    163.79    26.21      0.0      0.0    190.00     190.00
# 3340        3340      0.00     0.00      0.0      0.0      0.00       0.00
# 3341        3341  14889.29     0.00      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data4.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# IMPORTE       67
# IVA           59
# RET ISR       21
# RET IVA       74
# TOTAL MX      65
# TOTAL SAT     45
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data4.copy()
data_clean=data_clean.fillna(round(data4.mean(),1))
data_clean
# Out:
#       Unnamed: 0   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0              0      0.00  2248.28      0.0      0.0   2248.28   16300.00
# 1              1    490.00    78.40      0.0      0.0    568.40     568.40
# 2              2    195.00    31.20      0.0      0.0    226.20     226.20
# 3              3  10694.25  1711.08      0.0      0.0  12405.33   12405.33
# 4              4      0.00    83.90      0.0      0.0      0.00       0.00
# ...          ...       ...      ...      ...      ...       ...        ...
# 3337        3337    129.79    20.21      0.0      0.0    150.00     150.00
# 3338        3338   2284.80   365.57      0.0      0.0   2650.37    2650.37
# 3339        3339    163.79    26.21      0.0      0.0    190.00     190.00
# 3340        3340      0.00     0.00      0.0      0.0      0.00       0.00
# 3341        3341  14889.29     0.00      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0    0
# IMPORTE       0
# IVA           0
# RET ISR       0
# RET IVA       0
# TOTAL MX      0
# TOTAL SAT     0
# dtype: int64

# %%
# Unimos las columnas con el dataframe

cols=data2["FECHA"]
cols1=data2["FOLIO"]
cols2=data2["UUID"]
cols3=data2["TC"]
cols4=data2["Columna1"]
cols5=data2["RFC"]
cols6=data2["TIPO GASTO"]
cols7=data2["PROVEEDOR"]
cols8=data2["DESCRIPCION"]
cols9=data2["TIPO"]
cols10=data2["STATUS"]
cols11=data2["POLIZA"]

#"FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"
Datos_limpios = pd.concat([cols,cols1,cols2,cols3,cols4,cols5,cols6,cols7,cols8,cols9,cols10,cols11, data_clean], axis=1)
Datos_limpios

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("Datos_limpios2020_desv.csv")

# %% [markdown]
# **PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido Unnamed: 0    5011.50000
# IMPORTE       6929.04500
# IVA            946.69625
# RET ISR          0.00000
# RET IVA          0.00000
# TOTAL MX      7983.17750
# TOTAL SAT     8269.28375
# Columna1         0.00000
# dtype: float64
# Limite inferior permitido Unnamed: 0   -1670.50000
# IMPORTE      -4127.07500
# IVA           -547.89375
# RET ISR          0.00000
# RET IVA          0.00000
# TOTAL MX     -4783.14250
# TOTAL SAT    -4832.96625
# Columna1         0.00000
# dtype: float64
# <ipython-input-51-fa2f126c26b8>:4: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   percentile25=y.quantile(0.25) #Q1
# ...

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# <ipython-input-52-3f17fc13e977>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROVEEDOR TIPO GASTO GASTO DESCRIPCION  \
# 0            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 1            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 2            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 3            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 4            NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# ...          ...   ...   ...  ...  ...       ...        ...   ...         ...
# 3337         NaN   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# ...

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
# <ipython-input-53-bfdf7956f233>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3_iqr= data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROVEEDOR TIPO GASTO GASTO DESCRIPCION  \
# 0              0   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 1              1   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 2              2   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 3              3   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# 4              4   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# ...          ...   ...   ...  ...  ...       ...        ...   ...         ...
# 3337        3337   NaN   NaN  NaN  NaN       NaN        NaN   NaN         NaN
# ...

# %%
#Eliminamos columnas innecesarias
data4_iqr= data3_iqr.drop(["FECHA","FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"], axis=1)
data4_iqr
# Out:
#       Unnamed: 0  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0              0     0.00     NaN      0.0      0.0   2248.28        NaN
# 1              1   490.00   78.40      0.0      0.0    568.40     568.40
# 2              2   195.00   31.20      0.0      0.0    226.20     226.20
# 3              3      NaN     NaN      0.0      0.0       NaN        NaN
# 4              4     0.00   83.90      0.0      0.0      0.00       0.00
# ...          ...      ...     ...      ...      ...       ...        ...
# 3337        3337   129.79   20.21      0.0      0.0    150.00     150.00
# 3338        3338  2284.80  365.57      0.0      0.0   2650.37    2650.37
# 3339        3339   163.79   26.21      0.0      0.0    190.00     190.00
# 3340        3340     0.00    0.00      0.0      0.0      0.00       0.00
# 3341        3341      NaN    0.00      0.0      0.0       NaN        NaN
#
# [3342 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data4_iqr.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0      0
# IMPORTE       424
# IVA           460
# RET ISR        45
# RET IVA       253
# TOTAL MX      420
# TOTAL SAT     426
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data5_iqr=data4_iqr.copy()
data5_iqr=data5_iqr.fillna(round(data4_iqr.mean(),1))
data5_iqr
# Out:
#       Unnamed: 0  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0              0     0.00  148.50      0.0      0.0   2248.28    1333.00
# 1              1   490.00   78.40      0.0      0.0    568.40     568.40
# 2              2   195.00   31.20      0.0      0.0    226.20     226.20
# 3              3  1082.00  148.50      0.0      0.0   1239.10    1333.00
# 4              4     0.00   83.90      0.0      0.0      0.00       0.00
# ...          ...      ...     ...      ...      ...       ...        ...
# 3337        3337   129.79   20.21      0.0      0.0    150.00     150.00
# 3338        3338  2284.80  365.57      0.0      0.0   2650.37    2650.37
# 3339        3339   163.79   26.21      0.0      0.0    190.00     190.00
# 3340        3340     0.00    0.00      0.0      0.0      0.00       0.00
# 3341        3341  1082.00    0.00      0.0      0.0   1239.10    1333.00
#
# [3342 rows x 7 columns]

# %%
# Unimos las columnas con el dataframe

cols=data2["FECHA"]
cols1=data2["FOLIO"]
cols2=data2["UUID"]
cols3=data2["TC"]
cols4=data2["Columna1"]
cols5=data2["RFC"]
cols6=data2["TIPO GASTO"]
cols7=data2["PROVEEDOR"]
cols8=data2["DESCRIPCION"]
cols9=data2["TIPO"]
cols10=data2["STATUS"]
cols11=data2["POLIZA"]

#"FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"
Datos_limpios1 = pd.concat([cols,cols1,cols2,cols3,cols4,cols5,cols6,cols7,cols8,cols9,cols10,cols11, data5_iqr], axis=1)
Datos_limpios1
# Out:
#            FECHA                   FOLIO  \
# 0     2020-01-01                   39408
# 1     2020-01-01  0001010100750847116902
# 2     2020-01-01  0001010100752163714102
# 3     2020-01-01                    3663
# 4     2020-01-01                    2849
# ...          ...                     ...
# 3337  2020-12-01                  125834
# 3338  2020-12-01                   37652
# 3339  2020-12-01                     160
# 3340  2020-12-01                  634875
# 3341  2020-12-01                 1044477
#
#                                       UUID   TC  Columna1           RFC  \
# 0     BD20F436-72CC-4BE2-AD37-5999D71AA391  1.0  14051.72  ARE080115PBA
# 1     85AEAC2E-6395-44A0-9CB9-754D06893375  1.0      0.00  BNM840515VB1
# 2     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  1.0      0.00  BNM840515VB1
# 3     EF4504D6-830D-415C-AF03-80CF54C5E28E  1.0      0.00  PSS120625C86
# 4     EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3  1.0      0.00  ENA7006081P0
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# TC             0
# Columna1       0
# RFC            0
# TIPO GASTO     0
# PROVEEDOR      0
# DESCRIPCION    0
# TIPO           0
# STATUS         0
# POLIZA         0
# Unnamed: 0     0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# dtype: int64

# %%
#Convertir DataFrame a CSV
Datos_limpios1.to_csv("Datos_limpios2020_cuart.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Datos_limpios2020_cuart.csv")
