# %% [markdown]
# <a href="https://colab.research.google.com/github/A01703130/Valores-At-picos/blob/main/Actividad_3_2_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('gastos_2022_sin_nulos.csv')

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577 entries, 0 to 2576
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2577 non-null   int64
#  1   FECHA        2577 non-null   object
#  2   FOLIO        2577 non-null   object
#  3   UUID         2577 non-null   object
#  4   RFC          2577 non-null   object
#  5   PROOVEDOR    2577 non-null   object
#  6   TIPO GASTO   2577 non-null   object
#  7   DESCRIPCION  2577 non-null   object
#  8   MP           2577 non-null   object
#  9   TC           2577 non-null   object
#  10  Importe      2577 non-null   float64
#  11  IVA          2577 non-null   float64
#  12  RET ISR      2577 non-null   float64
#  13  RET IVA      2577 non-null   float64
#  14  TOTAL MX     2577 non-null   float64
#  15  TOTAL SAT    2577 non-null   float64
#  16  TIPO         2577 non-null   object
#  17  STATUS       2577 non-null   object
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROOVEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %% [markdown]
# **PROCEDIMIENTO PARA ELIMINAR VALORES NULOS EN DATAFRAME**

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
#       Unnamed: 0       FECHA         FOLIO  \
# 0              0  2022-01-01        280108
# 1              1  2022-01-01        280109
# 2              2  2022-01-01  007817297284
# 3              3  2022-01-01          5595
# 4              4  2022-01-01          5614
# ...          ...         ...           ...
# 2572        2572  2022-12-01        863376
# 2573        2573  2022-12-01    1092957089
# 2574        2574  2022-12-01             4
# 2575        2575  2022-12-01            16
# 2576        2576  2022-12-01            17
#
#                                       UUID            RFC  \
# 0     9DA0E63F-1D47-441F-93D7-C2E05AE4D35E   BLE1512082R9
# 1     7E00E776-A839-4D57-B291-411109164B2F   BLE1512082R9
# 2     BB6585C1-3B54-4130-AFD0-1867C3764821   BNM840515VB1
# 3     B5E4B4EB-6C2F-11EC-BB9D-00155D014009  ZEGC530520V4A
# 4     BB6756D1-6CCD-11EC-947D-00155D014407  ZEGC530520V4A
# ...                                    ...            ...
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROOVEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "mean"
#Realizamos una copia del dataframe
data2=data.copy()
data2=data2.fillna(round(data.mean(),1))
data2
# Out:
# <ipython-input-8-1c13554a70f8>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2=data2.fillna(round(data.mean(),1))
#       Unnamed: 0       FECHA         FOLIO  \
# 0              0  2022-01-01        280108
# 1              1  2022-01-01        280109
# 2              2  2022-01-01  007817297284
# 3              3  2022-01-01          5595
# 4              4  2022-01-01          5614
# ...          ...         ...           ...
# 2572        2572  2022-12-01        863376
# 2573        2573  2022-12-01    1092957089
# 2574        2574  2022-12-01             4
# 2575        2575  2022-12-01            16
# 2576        2576  2022-12-01            17
#
#                                       UUID            RFC  \
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROOVEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# **PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido Unnamed: 0     3520.180436
# Importe       34975.501132
# IVA            5048.646001
# RET ISR         977.619941
# RET IVA        1046.847384
# TOTAL MX      39054.094273
# TOTAL SAT     39095.543969
# dtype: float64
# Limite inferior permitido Unnamed: 0     -944.180436
# Importe      -26990.441616
# IVA           -4069.819702
# RET ISR        -902.558225
# RET IVA        -964.592475
# TOTAL MX     -30247.525081
# TOTAL SAT    -30172.959879
# dtype: float64
# <ipython-input-11-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# ...

# %%
#Encontramos Ouliers del Dataframe
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-12-b3686d19c4d6>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROOVEDOR TIPO GASTO DESCRIPCION   MP  \
# 0            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 2572         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
# <ipython-input-13-1e038dbc0c4a>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROOVEDOR TIPO GASTO DESCRIPCION   MP  \
# 0              0   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1              1   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2              2   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3              3   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4              4   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 2572        2572   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...

# %%
#Eliminamos columnas innecesarias
data4= data3.drop(["FECHA","FOLIO","UUID","TC","RFC","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"], axis=1)
data4
# Out:
#       Unnamed: 0 PROOVEDOR   MP   Importe     IVA  RET ISR  RET IVA  TOTAL MX  \
# 0              0       NaN  NaN   5551.38  888.22      0.0      0.0   6439.60
# 1              1       NaN  NaN   5551.98  888.32      0.0      0.0   6440.30
# 2              2       NaN  NaN      0.00    0.00      0.0      0.0      0.00
# 3              3       NaN  NaN      0.00    0.00      0.0      0.0      0.00
# 4              4       NaN  NaN      0.00    0.00      0.0      0.0      0.00
# ...          ...       ...  ...       ...     ...      ...      ...       ...
# 2572        2572       NaN  NaN      0.00    0.00      0.0      0.0      0.00
# 2573        2573       NaN  NaN  17310.30  516.32      0.0      0.0  17826.62
# 2574        2574       NaN  NaN      0.00    0.00      0.0      0.0      0.00
# 2575        2575       NaN  NaN      0.00    0.00      0.0      0.0      0.00
# 2576        2576       NaN  NaN      0.00    0.00      0.0      0.0      0.00
#
#       TOTAL SAT
# ...

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data4.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0       0
# PROOVEDOR     2577
# MP            2577
# Importe         36
# IVA             31
# RET ISR         32
# RET IVA         32
# TOTAL MX        36
# TOTAL SAT       36
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data4.copy()
data_clean=data_clean.fillna(round(data4.mean(),1))
data_clean
# Out:
#       Unnamed: 0  PROOVEDOR  MP   Importe     IVA  RET ISR  RET IVA  TOTAL MX  \
# 0              0        NaN NaN   5551.38  888.22      0.0      0.0   6439.60
# 1              1        NaN NaN   5551.98  888.32      0.0      0.0   6440.30
# 2              2        NaN NaN      0.00    0.00      0.0      0.0      0.00
# 3              3        NaN NaN      0.00    0.00      0.0      0.0      0.00
# 4              4        NaN NaN      0.00    0.00      0.0      0.0      0.00
# ...          ...        ...  ..       ...     ...      ...      ...       ...
# 2572        2572        NaN NaN      0.00    0.00      0.0      0.0      0.00
# 2573        2573        NaN NaN  17310.30  516.32      0.0      0.0  17826.62
# 2574        2574        NaN NaN      0.00    0.00      0.0      0.0      0.00
# 2575        2575        NaN NaN      0.00    0.00      0.0      0.0      0.00
# 2576        2576        NaN NaN      0.00    0.00      0.0      0.0      0.00
#
#       TOTAL SAT
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0       0
# PROOVEDOR     2577
# MP            2577
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# dtype: int64

# %%
# Unimos las columnas con el dataframe

cols=data2["FECHA"]
cols1=data2["FOLIO"]
cols2=data2["UUID"]
cols3=data2["TC"]
cols5=data2["RFC"]
cols6=data2["TIPO GASTO"]
cols8=data2["DESCRIPCION"]
cols9=data2["TIPO"]
cols10=data2["STATUS"]
cols11=data2["POLIZA"]

#"FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"
Datos_limpios = pd.concat([cols,cols1,cols2,cols3,cols5,cols6,cols8,cols9,cols10,cols11, data_clean], axis=1)
Datos_limpios
# Out:
#            FECHA         FOLIO                                  UUID   TC  \
# 0     2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E  1.0
# 1     2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F  1.0
# 2     2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821  1.0
# 3     2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009  1.0
# 4     2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407  1.0
# ...          ...           ...                                   ...  ...
# 2572  2022-12-01        863376  E90DA089-3C3B-45C8-A19C-B8810D222F60  1.0
# 2573  2022-12-01    1092957089  D720ED7C-F370-4236-B269-8873ABB78745  1.0
# 2574  2022-12-01             4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417   --
# 2575  2022-12-01            16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA   --
# 2576  2022-12-01            17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E   --
#
#                 RFC                TIPO GASTO  \
# ...

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("Datos_limpios2022_des.csv")

# %% [markdown]
# **PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido Unnamed: 0     3864.000
# Importe        9058.900
# IVA            1031.150
# RET ISR           0.000
# RET IVA           0.000
# TOTAL MX      10374.700
# TOTAL SAT     10485.475
# dtype: float64
# Limite inferior permitido Unnamed: 0   -1288.000
# Importe      -5435.340
# IVA           -618.690
# RET ISR          0.000
# RET IVA          0.000
# TOTAL MX     -6224.820
# TOTAL SAT    -6291.285
# dtype: float64
# <ipython-input-20-fa2f126c26b8>:4: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   percentile25=y.quantile(0.25) #Q1
# <ipython-input-20-fa2f126c26b8>:5: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# <ipython-input-21-3f17fc13e977>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROOVEDOR TIPO GASTO DESCRIPCION   MP  \
# 0            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4            NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 2572         NaN   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
# <ipython-input-22-bfdf7956f233>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3_iqr= data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
#       Unnamed: 0 FECHA FOLIO UUID  RFC PROOVEDOR TIPO GASTO DESCRIPCION   MP  \
# 0              0   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 1              1   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 2              2   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 3              3   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# 4              4   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...          ...   ...   ...  ...  ...       ...        ...         ...  ...
# 2572        2572   NaN   NaN  NaN  NaN       NaN        NaN         NaN  NaN
# ...

# %%
#Eliminamos columnas innecesarias
data4_iqr= data3_iqr.drop(["FECHA","FOLIO","UUID","TC","RFC","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"], axis=1)
data4_iqr
# Out:
#       Unnamed: 0 PROOVEDOR   MP  Importe     IVA  RET ISR  RET IVA  TOTAL MX  \
# 0              0       NaN  NaN  5551.38  888.22      0.0      0.0    6439.6
# 1              1       NaN  NaN  5551.98  888.32      0.0      0.0    6440.3
# 2              2       NaN  NaN     0.00    0.00      0.0      0.0       0.0
# 3              3       NaN  NaN     0.00    0.00      0.0      0.0       0.0
# 4              4       NaN  NaN     0.00    0.00      0.0      0.0       0.0
# ...          ...       ...  ...      ...     ...      ...      ...       ...
# 2572        2572       NaN  NaN     0.00    0.00      0.0      0.0       0.0
# 2573        2573       NaN  NaN      NaN  516.32      0.0      0.0       NaN
# 2574        2574       NaN  NaN     0.00    0.00      0.0      0.0       0.0
# 2575        2575       NaN  NaN     0.00    0.00      0.0      0.0       0.0
# 2576        2576       NaN  NaN     0.00    0.00      0.0      0.0       0.0
#
#       TOTAL SAT
# 0        6439.6
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data4_iqr.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0       0
# PROOVEDOR     2577
# MP            2577
# Importe        305
# IVA            303
# RET ISR         71
# RET IVA         70
# TOTAL MX       291
# TOTAL SAT      288
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data5_iqr=data4_iqr.copy()
data5_iqr=data5_iqr.fillna(round(data4_iqr.mean(),1))
data5_iqr
# Out:
#       Unnamed: 0  PROOVEDOR  MP  Importe     IVA  RET ISR  RET IVA  TOTAL MX  \
# 0              0        NaN NaN  5551.38  888.22      0.0      0.0    6439.6
# 1              1        NaN NaN  5551.98  888.32      0.0      0.0    6440.3
# 2              2        NaN NaN     0.00    0.00      0.0      0.0       0.0
# 3              3        NaN NaN     0.00    0.00      0.0      0.0       0.0
# 4              4        NaN NaN     0.00    0.00      0.0      0.0       0.0
# ...          ...        ...  ..      ...     ...      ...      ...       ...
# 2572        2572        NaN NaN     0.00    0.00      0.0      0.0       0.0
# 2573        2573        NaN NaN  1449.20  516.32      0.0      0.0    1711.5
# 2574        2574        NaN NaN     0.00    0.00      0.0      0.0       0.0
# 2575        2575        NaN NaN     0.00    0.00      0.0      0.0       0.0
# 2576        2576        NaN NaN     0.00    0.00      0.0      0.0       0.0
#
#       TOTAL SAT
# 0        6439.6
# ...

# %%
# Unimos las columnas con el dataframe

cols=data2["FECHA"]
cols1=data2["FOLIO"]
cols2=data2["UUID"]
cols3=data2["TC"]
cols5=data2["RFC"]
cols6=data2["TIPO GASTO"]
cols8=data2["DESCRIPCION"]
cols9=data2["TIPO"]
cols10=data2["STATUS"]
cols11=data2["POLIZA"]

#"FOLIO","UUID","TC","Columna1","GASTO","RFC","PROVEEDOR","TIPO GASTO","DESCRIPCION","TIPO","STATUS","POLIZA"
Datos_limpios1 = pd.concat([cols,cols1,cols2,cols3,cols5,cols6,cols8,cols9,cols10,cols11, data5_iqr], axis=1)
Datos_limpios1
# Out:
#            FECHA         FOLIO                                  UUID   TC  \
# 0     2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E  1.0
# 1     2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F  1.0
# 2     2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821  1.0
# 3     2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009  1.0
# 4     2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407  1.0
# ...          ...           ...                                   ...  ...
# 2572  2022-12-01        863376  E90DA089-3C3B-45C8-A19C-B8810D222F60  1.0
# 2573  2022-12-01    1092957089  D720ED7C-F370-4236-B269-8873ABB78745  1.0
# 2574  2022-12-01             4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417   --
# 2575  2022-12-01            16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA   --
# 2576  2022-12-01            17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E   --
#
#                 RFC                TIPO GASTO  \
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO             0
# UUID              0
# TC                0
# RFC               0
# TIPO GASTO        0
# DESCRIPCION       0
# TIPO              0
# STATUS            0
# POLIZA            0
# Unnamed: 0        0
# PROOVEDOR      2577
# MP             2577
# Importe           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# dtype: int64

# %%
#Convertir DataFrame a CSV
Datos_limpios1.to_csv("Datos_limpios2022_cuart.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Datos_limpios2022_cuart.csv")
